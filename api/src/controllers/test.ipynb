# %%
from pymongo import MongoClient
from dotenv import load_dotenv
import os
from flask import request

# %%
load_dotenv()
username = os.getenv("USER")
password = os.getenv("PASS")
url = f"mongodb+srv://{username}:{password}@datacluster.2umgq.mongodb.net/myFirstDatabase?retryWrites=true&w=majority"
client = MongoClient(url)
db = client.get_database("movies")
movies_metadata = db.movies_metadata

# %%
movies_metadata.count_documents({})
# Out:
# 45466

# %%
list(movies_metadata.find({},{"original_title":1, "_id": 0}))
# Out:
# [{'original_title': 'Toy Story'},
#  {'original_title': 'Jumanji'},
#  {'original_title': 'Grumpier Old Men'},
#  {'original_title': 'Waiting to Exhale'},
#  {'original_title': 'Father of the Bride Part II'},
#  {'original_title': 'Heat'},
#  {'original_title': 'Sabrina'},
#  {'original_title': 'Tom and Huck'},
#  {'original_title': 'Sudden Death'},
#  {'original_title': 'GoldenEye'},
#  {'original_title': 'The American President'},
#  {'original_title': 'Dracula: Dead and Loving It'},
#  {'original_title': 'Balto'},
#  {'original_title': 'Nixon'},
#  {'original_title': 'Cutthroat Island'},
#  {'original_title': 'Casino'},
#  {'original_title': 'Sense and Sensibility'},
#  {'original_title': 'Four Rooms'},
#  {'original_title': 'Ace Ventura: When Nature Calls'},
#  {'original_title': 'Money Train'},
#  {'original_title': 'Get Shorty'},
#  {'original_title': 'Copycat'},
#  {'original_title': 'Assassins'},
#  {'original_title': 'Powder'},
#  {'original_title': 'Leaving Las Vegas'},
# ...

# %%
##pattern = request.args.get("name")
pattern = "toy"
list(movies_metadata.find({"original_title": {"$regex": pattern, "$options": "i"}}, {"original_title": 1, "_id": 0, "release_date": 1}))
# Out:
# [{'original_title': 'Toy Story', 'release_date': '1995-10-30'},
#  {'original_title': 'Babes in Toyland', 'release_date': '1961-12-14'},
#  {'original_title': 'Toys', 'release_date': '1992-12-18'},
#  {'original_title': 'Nettoyage à sec', 'release_date': '1997-09-24'},
#  {'original_title': 'Babes in Toyland', 'release_date': '1934-12-14'},
#  {'original_title': 'Toy Story 2', 'release_date': '1999-10-30'},
#  {'original_title': 'The Toy', 'release_date': '1982-12-10'},
#  {'original_title': 'Toy Soldiers', 'release_date': '1991-04-24'},
#  {'original_title': 'Puppet Master vs Demonic Toys',
#   'release_date': '2004-12-18'},
#  {'original_title': 'Toy Story 3', 'release_date': '2010-06-16'},
#  {'original_title': 'The Christmas Toy', 'release_date': '1986-12-06'},
#  {'original_title': 'Demonic Toys', 'release_date': '1992-03-12'},
#  {'original_title': 'Toys in the Attic', 'release_date': '1963-07-31'},
#  {'original_title': 'Resurrect Dead: The Mystery of the Toynbee Tiles',
# ...
