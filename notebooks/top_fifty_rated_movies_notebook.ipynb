# %%
import pandas as pd
import numpy as np

# %%
def get_top_50_movies():
    metadata = pd.read_csv("../data/movies_metadata.csv")
    C = metadata['vote_average'].mean()
    m = metadata['vote_count'].quantile(0.90)
    q_movies = metadata.copy().loc[metadata['vote_count'] >= m]
    q_movies['weighted score'] = q_movies.apply(weighted_rating, axis= 1)
    q_movies.sort_values(by= 'weighted score', ascending= False, inplace= True)
    top_score_movies = q_movies[['title', 'vote_count', 'vote_average', 'weighted score']].head(50).reset_index().drop(columns=["index"])
    top_score_movies.index += 1
    return top_score_movies

# %%
def weighted_rating(x, m=m, C=C):
    v = x['vote_count']
    R = x['vote_average']
    # Calculation based on the IMDB formula
    return (v/(v+m) * R) + (m/(m+v) * C)

# %%
get_top_50_movies()
# Out:
# /home/marrechea/miniconda3/envs/movies/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3337: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#                                                 title  vote_count  \
# 1                            The Shawshank Redemption      8358.0
# 2                                       The Godfather      6024.0
# 3                         Dilwale Dulhania Le Jayenge       661.0
# 4                                     The Dark Knight     12269.0
# 5                                          Fight Club      9678.0
# 6                                        Pulp Fiction      8670.0
# 7                                    Schindler's List      4436.0
# 8                                            Whiplash      4376.0
# 9                                       Spirited Away      3968.0
# 10                                  Life Is Beautiful      3643.0
# 11                             The Godfather: Part II      3418.0
# 12                    One Flew Over the Cuckoo's Nest      3001.0
# 13                                       Forrest Gump      8147.0
# 14                            The Empire Strikes Back      5998.0
# 15                                             Psycho      2405.0
# 16                                   The Intouchables      5410.0
# 17                                         Your Name.      1030.0
# 18                             Leon: The Professional      4293.0
# 19                                     The Green Mile      4166.0
# 20                                         GoodFellas      3211.0
# 21                                 American History X      3120.0
# 22                                          Inception     14075.0
# 23                                       Interstellar     11187.0
# 24      The Lord of the Rings: The Return of the King      8226.0
# 25                                          Star Wars      6778.0
# 26                                              Se7en      5915.0
# 27                                       12 Angry Men      2130.0
# 28                           The Silence of the Lambs      4549.0
# 29                               Howl's Moving Castle      2049.0
# 30                                  Princess Mononoke      2041.0
# 31                                            Memento      4168.0
# 32                                        The Shining      3890.0
# 33                                     Reservoir Dogs      3821.0
# 34                                        City of God      1852.0
# 35                                 The Usual Suspects      3334.0
# 36                                               Room      2838.0
# 37                                 Dead Poets Society      2786.0
# 38                        Once Upon a Time in America      1104.0
# 39  The Lord of the Rings: The Fellowship of the Ring      8892.0
# 40                                        Taxi Driver      2632.0
# 41                                        Rear Window      1531.0
# 42              The Lord of the Rings: The Two Towers      7641.0
# 43                     The Good, the Bad and the Ugly      2371.0
# 44                                 Back to the Future      6239.0
# 45                                 The Imitation Game      5895.0
# 46                                      The Lion King      5520.0
# 47                           The Grand Budapest Hotel      4644.0
# 48                                       The Prestige      4510.0
# 49                                        The Pianist      1927.0
# 50                                 A Clockwork Orange      3432.0
#
#     vote_average  weighted score
# 1            8.5        8.445869
# 2            8.5        8.425439
# 3            9.1        8.421453
# 4            8.3        8.265477
# 5            8.3        8.256385
# 6            8.3        8.251406
# 7            8.3        8.206639
# 8            8.3        8.205404
# 9            8.3        8.196055
# 10           8.3        8.187171
# 11           8.3        8.180076
# 12           8.3        8.164256
# 13           8.2        8.150272
# 14           8.2        8.132919
# 15           8.3        8.132715
# 16           8.2        8.125837
# 17           8.5        8.112532
# 18           8.2        8.107234
# 19           8.2        8.104511
# 20           8.2        8.077459
# 21           8.2        8.074059
# 22           8.1        8.072105
# 23           8.1        8.065005
# 24           8.1        8.052649
# 25           8.1        8.042766
# 26           8.1        8.034636
# 27           8.2        8.019613
# 28           8.1        8.015675
# 29           8.2        8.012998
# 30           8.2        8.012319
# 31           8.1        8.008252
# 32           8.1        8.001954
# 33           8.1        8.000254
# 34           8.2        7.994688
# 35           8.1        7.986352
# 36           8.1        7.967549
# 37           8.1        7.965212
# 38           8.3        7.960533
# 39           8.0        7.957900
# 40           8.1        7.957777
# 41           8.2        7.955714
# 42           8.0        7.951149
# 43           8.1        7.943111
# 44           8.0        7.940446
# 45           8.0        7.937062
# 46           8.0        7.932907
# 47           8.0        7.920673
# 48           8.0        7.918397
# 49           8.1        7.909733
# 50           8.0        7.893907
